# %% [markdown]
#  SOLUCION
#
# Integrante:Paul Cadena

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
import numpy as np

# 1. Cargar los archivos
X_train = pd.read_csv('datos/X_train_seeds.csv')
y_train = pd.read_csv('datos/y_train_seeds.csv')
X_test = pd.read_csv('datos/X_test_seeds.csv')
sample_submission = pd.read_csv('datos/sample_submission_seeds.csv')

# 2. Normalización de los datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 3. Entrenar el modelo
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train_scaled, y_train.values.ravel())  # Asegurarse de que y_train sea un array plano

# 4. Hacer predicciones sobre el conjunto de test
y_pred = clf.predict(X_test_scaled)

# 5. Crear el archivo de submission
submission = sample_submission.copy()
submission['class'] = y_pred  # Reemplaza 'label' con el nombre correcto si es distinto

# 6. Guardar el archivo de salida
submission.to_csv('Midterm1.csv', index=False)

print("¡Predicciones guardadas en Midterm1.csv!")


# 4. Validación cruzada (k=5 por defecto, puedes cambiarlo)
scores = cross_val_score(clf, X_train_scaled, y_train.values.ravel(), cv=5)

# 5. Resultados
print(f"Accuracy por fold: {scores}")
print(f"Accuracy media (CV): {np.mean(scores):.4f}")
# Out:
# ¡Predicciones guardadas en Midterm1.csv!
# Accuracy por fold: [0.9        0.9        0.93103448 0.96551724 0.96551724]
# Accuracy media (CV): 0.9324

# %%
X_train
# Out:
#       area  perimeter  compactness  length_of_kernel  width_of_kernel  \
# 0    20.16      17.03       0.8735             6.513            3.773
# 1    17.12      15.55       0.8892             5.850            3.566
# 2    12.19      13.20       0.8783             5.137            2.981
# 3    11.84      13.21       0.8521             5.175            2.836
# 4    15.49      14.94       0.8724             5.757            3.371
# ..     ...        ...          ...               ...              ...
# 142  18.85      16.17       0.9056             6.152            3.806
# 143  13.74      14.05       0.8744             5.482            3.114
# 144  18.81      16.29       0.8906             6.272            3.693
# 145  12.21      13.47       0.8453             5.357            2.893
# 146  19.46      16.50       0.8985             6.113            3.892
#
#      asymmetry_coefficient  length_of_kernel_groove
# 0                    1.910                    6.185
# ...

# %%
X_train.describe()
# Out:
#              area   perimeter  compactness  length_of_kernel  width_of_kernel  \
# count  147.000000  147.000000   147.000000        147.000000       147.000000
# mean    14.902993   14.592245     0.870069          5.646605         3.263252
# std      2.950990    1.319665     0.024482          0.441271         0.382722
# min     10.590000   12.410000     0.808100          4.899000         2.630000
# 25%     12.280000   13.470000     0.855750          5.318000         2.946000
# 50%     14.430000   14.410000     0.873400          5.545000         3.258000
# 75%     17.435000   15.790000     0.887700          5.989000         3.564500
# max     21.180000   17.250000     0.910800          6.666000         4.033000
#
#        asymmetry_coefficient  length_of_kernel_groove
# count             147.000000               147.000000
# mean                3.736504                 5.420898
# std                 1.505393                 0.486322
# ...
